# %% [markdown]
# # Práctica 2: Introducción a PyTorch
# ## Participantes: Tobias Perel, Ezequiel Bacher, Lazaro Harari y Tomas Hoch
# ## a) Calculando el gradiente mediante Autograd
#
# En primer lugar, vamos a calcular del gradiente para el perceptrón simple con función de activación sigmoidea que vimos en la teoría. Pero esta vez, en lugar de realizar manualmente el proceso de backpropagation, vamos a usar el módulo `autograd` de PyTorch.
#
# La función $f(x, w)$ a la cual queremos encontrarle el gradiente es:
#
# > $f(\mathbf{x}, \mathbf{w}) = \frac{1}{1 + e^{2-(w_0 x_0 + w_1 x_1 + w_2)}}$
#
# Definimos entonces la función utilizando `torch.tensor` (recordar usar el parámetro `requires_grad = True` para que PyTorch guarde los gradientes) y realizamos la pasada "forward" para los siguientes valores de x y w:
#
# > $\mathbf{x} = (-1, -2)$
#
# > $\mathbf{w} = (2, -3, -3)$

# %%
import torch

def mi_funcion(x, w):
    exponent = 2 - (w[0] * x[0] + w[1] * x[1] + w[2])
    return 1 / (1 + torch.exp(exponent))

x = torch.tensor((-1.0,-2.0), requires_grad=False) # como no nos interesa actualizar los parametros de x se deja en false.
w = torch.tensor( (2.0,-3.0,-3.0) , requires_grad=True)

f = mi_funcion(x, w)

print(f)
# Out:
# tensor(0.2689, grad_fn=<MulBackward0>)

# %% [markdown]
# Ahora, utilizando la función `f.backward()` computamos los gradientes $\frac{\partial f}{ \partial \mathbf{x}}$ y $\frac{\partial f}{ \partial \mathbf{w}}$

# %%
f.backward()

# %%
gradiente_x = x.grad
gradiente_w = w.grad

print("Gradiente df/dx = " + str( gradiente_x ))
print("Gradiente df/dw = " + str( gradiente_w))
# Out:
# Gradiente df/dx = None
# Gradiente df/dw = tensor([-0.1966, -0.3932,  0.1966])

# %% [markdown]
# ## b) Minimizando una función con Gradient Descent
#
# Ahora, vamos a implementar usar el algorítmo de gradiente descendiente (utilizando Autograd para computar el gradiente) para minimizar la función cuadrática $$f(x) = 2x^2 + x + 4$$
#
# Utilizaremos la implementación `torch.optim.SGD` de gradiente descendiente.

# %%
import matplotlib.pyplot as plt

# Definir la variable que será el parámetro a optimizar
x = torch.tensor(8.0,requires_grad=True)

# Definir el optimizador, indicando el parámetro a optimizar y el learning rate
optimizer = torch.optim.SGD( [x] , lr = 0.001)

# Acumuladores que usaremos para guardar los valores sucesivos de x, y
f_values = []
x_values = []

# Loop de optimización
for i in range(2000):

    # Setemos en 0 los gradientes de todos los elementos
    optimizer.zero_grad()

    # Pasada forward: ejecutar la función a minimizar
    f = 2 * x**2 + x + 4

    print("X = " + str(x) + ", f(x) = " + str(f))

    # Pasada backward: computar los gradientes
    f.backward()

    # Actualizar los pesos dando un paso de gradiente descendiente
    optimizer.step()
    # Guardar los valores para luego plotearlos
    f_values.append(f.data.item())
    x_values.append(x.data.item())

# Ploteo los valores
plt.title("Optimizando la función f = 2 * x**2 + x + 4")
plt.xlabel("X")
plt.plot(x_values,f_values)
# Out:
# X = tensor(8., requires_grad=True), f(x) = tensor(140., grad_fn=<AddBackward0>)
# X = tensor(7.9670, requires_grad=True), f(x) = tensor(138.9132, grad_fn=<AddBackward0>)
# X = tensor(7.9341, requires_grad=True), f(x) = tensor(137.8350, grad_fn=<AddBackward0>)
# X = tensor(7.9014, requires_grad=True), f(x) = tensor(136.7655, grad_fn=<AddBackward0>)
# X = tensor(7.8688, requires_grad=True), f(x) = tensor(135.7045, grad_fn=<AddBackward0>)
# X = tensor(7.8363, requires_grad=True), f(x) = tensor(134.6520, grad_fn=<AddBackward0>)
# X = tensor(7.8040, requires_grad=True), f(x) = tensor(133.6079, grad_fn=<AddBackward0>)
# X = tensor(7.7718, requires_grad=True), f(x) = tensor(132.5721, grad_fn=<AddBackward0>)
# X = tensor(7.7397, requires_grad=True), f(x) = tensor(131.5446, grad_fn=<AddBackward0>)
# X = tensor(7.7077, requires_grad=True), f(x) = tensor(130.5252, grad_fn=<AddBackward0>)
# X = tensor(7.6759, requires_grad=True), f(x) = tensor(129.5141, grad_fn=<AddBackward0>)
# X = tensor(7.6442, requires_grad=True), f(x) = tensor(128.5110, grad_fn=<AddBackward0>)
# X = tensor(7.6126, requires_grad=True), f(x) = tensor(127.5159, grad_fn=<AddBackward0>)
# X = tensor(7.5811, requires_grad=True), f(x) = tensor(126.5287, grad_fn=<AddBackward0>)
# X = tensor(7.5498, requires_grad=True), f(x) = tensor(125.5495, grad_fn=<AddBackward0>)
# X = tensor(7.5186, requires_grad=True), f(x) = tensor(124.5780, grad_fn=<AddBackward0>)
# X = tensor(7.4875, requires_grad=True), f(x) = tensor(123.6143, grad_fn=<AddBackward0>)
# X = tensor(7.4566, requires_grad=True), f(x) = tensor(122.6583, grad_fn=<AddBackward0>)
# X = tensor(7.4258, requires_grad=True), f(x) = tensor(121.7100, grad_fn=<AddBackward0>)
# X = tensor(7.3951, requires_grad=True), f(x) = tensor(120.7692, grad_fn=<AddBackward0>)
# X = tensor(7.3645, requires_grad=True), f(x) = tensor(119.8359, grad_fn=<AddBackward0>)
# X = tensor(7.3340, requires_grad=True), f(x) = tensor(118.9101, grad_fn=<AddBackward0>)
# X = tensor(7.3037, requires_grad=True), f(x) = tensor(117.9916, grad_fn=<AddBackward0>)
# X = tensor(7.2735, requires_grad=True), f(x) = tensor(117.0805, grad_fn=<AddBackward0>)
# X = tensor(7.2434, requires_grad=True), f(x) = tensor(116.1767, grad_fn=<AddBackward0>)
# X = tensor(7.2134, requires_grad=True), f(x) = tensor(115.2801, grad_fn=<AddBackward0>)
# X = tensor(7.1836, requires_grad=True), f(x) = tensor(114.3906, grad_fn=<AddBackward0>)
# X = tensor(7.1538, requires_grad=True), f(x) = tensor(113.5082, grad_fn=<AddBackward0>)
# X = tensor(7.1242, requires_grad=True), f(x) = tensor(112.6329, grad_fn=<AddBackward0>)
# X = tensor(7.0947, requires_grad=True), f(x) = tensor(111.7646, grad_fn=<AddBackward0>)
# X = tensor(7.0653, requires_grad=True), f(x) = tensor(110.9032, grad_fn=<AddBackward0>)
# X = tensor(7.0361, requires_grad=True), f(x) = tensor(110.0487, grad_fn=<AddBackward0>)
# X = tensor(7.0069, requires_grad=True), f(x) = tensor(109.2010, grad_fn=<AddBackward0>)
# X = tensor(6.9779, requires_grad=True), f(x) = tensor(108.3601, grad_fn=<AddBackward0>)
# X = tensor(6.9490, requires_grad=True), f(x) = tensor(107.5259, grad_fn=<AddBackward0>)
# X = tensor(6.9202, requires_grad=True), f(x) = tensor(106.6983, grad_fn=<AddBackward0>)
# X = tensor(6.8915, requires_grad=True), f(x) = tensor(105.8774, grad_fn=<AddBackward0>)
# X = tensor(6.8629, requires_grad=True), f(x) = tensor(105.0630, grad_fn=<AddBackward0>)
# X = tensor(6.8345, requires_grad=True), f(x) = tensor(104.2551, grad_fn=<AddBackward0>)
# X = tensor(6.8062, requires_grad=True), f(x) = tensor(103.4537, grad_fn=<AddBackward0>)
# X = tensor(6.7779, requires_grad=True), f(x) = tensor(102.6587, grad_fn=<AddBackward0>)
# X = tensor(6.7498, requires_grad=True), f(x) = tensor(101.8700, grad_fn=<AddBackward0>)
# X = tensor(6.7218, requires_grad=True), f(x) = tensor(101.0876, grad_fn=<AddBackward0>)
# X = tensor(6.6939, requires_grad=True), f(x) = tensor(100.3114, grad_fn=<AddBackward0>)
# X = tensor(6.6662, requires_grad=True), f(x) = tensor(99.5415, grad_fn=<AddBackward0>)
# X = tensor(6.6385, requires_grad=True), f(x) = tensor(98.7777, grad_fn=<AddBackward0>)
# X = tensor(6.6109, requires_grad=True), f(x) = tensor(98.0200, grad_fn=<AddBackward0>)
# X = tensor(6.5835, requires_grad=True), f(x) = tensor(97.2683, grad_fn=<AddBackward0>)
# X = tensor(6.5562, requires_grad=True), f(x) = tensor(96.5227, grad_fn=<AddBackward0>)
# X = tensor(6.5289, requires_grad=True), f(x) = tensor(95.7830, grad_fn=<AddBackward0>)
# X = tensor(6.5018, requires_grad=True), f(x) = tensor(95.0492, grad_fn=<AddBackward0>)
# X = tensor(6.4748, requires_grad=True), f(x) = tensor(94.3212, grad_fn=<AddBackward0>)
# X = tensor(6.4479, requires_grad=True), f(x) = tensor(93.5991, grad_fn=<AddBackward0>)
# X = tensor(6.4211, requires_grad=True), f(x) = tensor(92.8828, grad_fn=<AddBackward0>)
# X = tensor(6.3944, requires_grad=True), f(x) = tensor(92.1721, grad_fn=<AddBackward0>)
# X = tensor(6.3679, requires_grad=True), f(x) = tensor(91.4671, grad_fn=<AddBackward0>)
# X = tensor(6.3414, requires_grad=True), f(x) = tensor(90.7678, grad_fn=<AddBackward0>)
# X = tensor(6.3150, requires_grad=True), f(x) = tensor(90.0741, grad_fn=<AddBackward0>)
# X = tensor(6.2888, requires_grad=True), f(x) = tensor(89.3858, grad_fn=<AddBackward0>)
# X = tensor(6.2626, requires_grad=True), f(x) = tensor(88.7031, grad_fn=<AddBackward0>)
# X = tensor(6.2366, requires_grad=True), f(x) = tensor(88.0259, grad_fn=<AddBackward0>)
# X = tensor(6.2106, requires_grad=True), f(x) = tensor(87.3540, grad_fn=<AddBackward0>)
# X = tensor(6.1848, requires_grad=True), f(x) = tensor(86.6875, grad_fn=<AddBackward0>)
# X = tensor(6.1590, requires_grad=True), f(x) = tensor(86.0263, grad_fn=<AddBackward0>)
# X = tensor(6.1334, requires_grad=True), f(x) = tensor(85.3704, grad_fn=<AddBackward0>)
# X = tensor(6.1079, requires_grad=True), f(x) = tensor(84.7198, grad_fn=<AddBackward0>)
# X = tensor(6.0824, requires_grad=True), f(x) = tensor(84.0743, grad_fn=<AddBackward0>)
# X = tensor(6.0571, requires_grad=True), f(x) = tensor(83.4340, grad_fn=<AddBackward0>)
# X = tensor(6.0319, requires_grad=True), f(x) = tensor(82.7988, grad_fn=<AddBackward0>)
# X = tensor(6.0067, requires_grad=True), f(x) = tensor(82.1687, grad_fn=<AddBackward0>)
# X = tensor(5.9817, requires_grad=True), f(x) = tensor(81.5436, grad_fn=<AddBackward0>)
# X = tensor(5.9568, requires_grad=True), f(x) = tensor(80.9235, grad_fn=<AddBackward0>)
# X = tensor(5.9320, requires_grad=True), f(x) = tensor(80.3083, grad_fn=<AddBackward0>)
# X = tensor(5.9072, requires_grad=True), f(x) = tensor(79.6981, grad_fn=<AddBackward0>)
# X = tensor(5.8826, requires_grad=True), f(x) = tensor(79.0927, grad_fn=<AddBackward0>)
# X = tensor(5.8581, requires_grad=True), f(x) = tensor(78.4922, grad_fn=<AddBackward0>)
# X = tensor(5.8336, requires_grad=True), f(x) = tensor(77.8964, grad_fn=<AddBackward0>)
# X = tensor(5.8093, requires_grad=True), f(x) = tensor(77.3054, grad_fn=<AddBackward0>)
# X = tensor(5.7851, requires_grad=True), f(x) = tensor(76.7192, grad_fn=<AddBackward0>)
# X = tensor(5.7609, requires_grad=True), f(x) = tensor(76.1376, grad_fn=<AddBackward0>)
# X = tensor(5.7369, requires_grad=True), f(x) = tensor(75.5606, grad_fn=<AddBackward0>)
# X = tensor(5.7129, requires_grad=True), f(x) = tensor(74.9883, grad_fn=<AddBackward0>)
# X = tensor(5.6891, requires_grad=True), f(x) = tensor(74.4205, grad_fn=<AddBackward0>)
# X = tensor(5.6653, requires_grad=True), f(x) = tensor(73.8573, grad_fn=<AddBackward0>)
# X = tensor(5.6417, requires_grad=True), f(x) = tensor(73.2985, grad_fn=<AddBackward0>)
# X = tensor(5.6181, requires_grad=True), f(x) = tensor(72.7443, grad_fn=<AddBackward0>)
# X = tensor(5.5946, requires_grad=True), f(x) = tensor(72.1944, grad_fn=<AddBackward0>)
# X = tensor(5.5713, requires_grad=True), f(x) = tensor(71.6490, grad_fn=<AddBackward0>)
# X = tensor(5.5480, requires_grad=True), f(x) = tensor(71.1079, grad_fn=<AddBackward0>)
# X = tensor(5.5248, requires_grad=True), f(x) = tensor(70.5711, grad_fn=<AddBackward0>)
# X = tensor(5.5017, requires_grad=True), f(x) = tensor(70.0386, grad_fn=<AddBackward0>)
# X = tensor(5.4787, requires_grad=True), f(x) = tensor(69.5103, grad_fn=<AddBackward0>)
# X = tensor(5.4558, requires_grad=True), f(x) = tensor(68.9863, grad_fn=<AddBackward0>)
# X = tensor(5.4329, requires_grad=True), f(x) = tensor(68.4664, grad_fn=<AddBackward0>)
# X = tensor(5.4102, requires_grad=True), f(x) = tensor(67.9507, grad_fn=<AddBackward0>)
# X = tensor(5.3876, requires_grad=True), f(x) = tensor(67.4391, grad_fn=<AddBackward0>)
# X = tensor(5.3650, requires_grad=True), f(x) = tensor(66.9317, grad_fn=<AddBackward0>)
# X = tensor(5.3425, requires_grad=True), f(x) = tensor(66.4282, grad_fn=<AddBackward0>)
# X = tensor(5.3202, requires_grad=True), f(x) = tensor(65.9288, grad_fn=<AddBackward0>)
# X = tensor(5.2979, requires_grad=True), f(x) = tensor(65.4333, grad_fn=<AddBackward0>)
# X = tensor(5.2757, requires_grad=True), f(x) = tensor(64.9419, grad_fn=<AddBackward0>)
# X = tensor(5.2536, requires_grad=True), f(x) = tensor(64.4543, grad_fn=<AddBackward0>)
# X = tensor(5.2316, requires_grad=True), f(x) = tensor(63.9706, grad_fn=<AddBackward0>)
# X = tensor(5.2097, requires_grad=True), f(x) = tensor(63.4908, grad_fn=<AddBackward0>)
# X = tensor(5.1878, requires_grad=True), f(x) = tensor(63.0149, grad_fn=<AddBackward0>)
# X = tensor(5.1661, requires_grad=True), f(x) = tensor(62.5427, grad_fn=<AddBackward0>)
# X = tensor(5.1444, requires_grad=True), f(x) = tensor(62.0743, grad_fn=<AddBackward0>)
# X = tensor(5.1228, requires_grad=True), f(x) = tensor(61.6096, grad_fn=<AddBackward0>)
# X = tensor(5.1013, requires_grad=True), f(x) = tensor(61.1487, grad_fn=<AddBackward0>)
# X = tensor(5.0799, requires_grad=True), f(x) = tensor(60.6914, grad_fn=<AddBackward0>)
# X = tensor(5.0586, requires_grad=True), f(x) = tensor(60.2378, grad_fn=<AddBackward0>)
# X = tensor(5.0374, requires_grad=True), f(x) = tensor(59.7878, grad_fn=<AddBackward0>)
# X = tensor(5.0162, requires_grad=True), f(x) = tensor(59.3414, grad_fn=<AddBackward0>)
# X = tensor(4.9952, requires_grad=True), f(x) = tensor(58.8985, grad_fn=<AddBackward0>)
# X = tensor(4.9742, requires_grad=True), f(x) = tensor(58.4592, grad_fn=<AddBackward0>)
# X = tensor(4.9533, requires_grad=True), f(x) = tensor(58.0234, grad_fn=<AddBackward0>)
# X = tensor(4.9325, requires_grad=True), f(x) = tensor(57.5911, grad_fn=<AddBackward0>)
# X = tensor(4.9117, requires_grad=True), f(x) = tensor(57.1622, grad_fn=<AddBackward0>)
# X = tensor(4.8911, requires_grad=True), f(x) = tensor(56.7368, grad_fn=<AddBackward0>)
# X = tensor(4.8705, requires_grad=True), f(x) = tensor(56.3147, grad_fn=<AddBackward0>)
# X = tensor(4.8501, requires_grad=True), f(x) = tensor(55.8960, grad_fn=<AddBackward0>)
# X = tensor(4.8297, requires_grad=True), f(x) = tensor(55.4807, grad_fn=<AddBackward0>)
# X = tensor(4.8093, requires_grad=True), f(x) = tensor(55.0687, grad_fn=<AddBackward0>)
# X = tensor(4.7891, requires_grad=True), f(x) = tensor(54.6600, grad_fn=<AddBackward0>)
# X = tensor(4.7689, requires_grad=True), f(x) = tensor(54.2545, grad_fn=<AddBackward0>)
# X = tensor(4.7489, requires_grad=True), f(x) = tensor(53.8523, grad_fn=<AddBackward0>)
# X = tensor(4.7289, requires_grad=True), f(x) = tensor(53.4532, grad_fn=<AddBackward0>)
# X = tensor(4.7090, requires_grad=True), f(x) = tensor(53.0574, grad_fn=<AddBackward0>)
# X = tensor(4.6891, requires_grad=True), f(x) = tensor(52.6647, grad_fn=<AddBackward0>)
# X = tensor(4.6694, requires_grad=True), f(x) = tensor(52.2752, grad_fn=<AddBackward0>)
# X = tensor(4.6497, requires_grad=True), f(x) = tensor(51.8888, grad_fn=<AddBackward0>)
# X = tensor(4.6301, requires_grad=True), f(x) = tensor(51.5054, grad_fn=<AddBackward0>)
# X = tensor(4.6106, requires_grad=True), f(x) = tensor(51.1251, grad_fn=<AddBackward0>)
# X = tensor(4.5911, requires_grad=True), f(x) = tensor(50.7479, grad_fn=<AddBackward0>)
# X = tensor(4.5718, requires_grad=True), f(x) = tensor(50.3737, grad_fn=<AddBackward0>)
# X = tensor(4.5525, requires_grad=True), f(x) = tensor(50.0024, grad_fn=<AddBackward0>)
# X = tensor(4.5333, requires_grad=True), f(x) = tensor(49.6341, grad_fn=<AddBackward0>)
# X = tensor(4.5141, requires_grad=True), f(x) = tensor(49.2688, grad_fn=<AddBackward0>)
# X = tensor(4.4951, requires_grad=True), f(x) = tensor(48.9064, grad_fn=<AddBackward0>)
# X = tensor(4.4761, requires_grad=True), f(x) = tensor(48.5468, grad_fn=<AddBackward0>)
# X = tensor(4.4572, requires_grad=True), f(x) = tensor(48.1902, grad_fn=<AddBackward0>)
# X = tensor(4.4384, requires_grad=True), f(x) = tensor(47.8364, grad_fn=<AddBackward0>)
# X = tensor(4.4196, requires_grad=True), f(x) = tensor(47.4854, grad_fn=<AddBackward0>)
# X = tensor(4.4009, requires_grad=True), f(x) = tensor(47.1372, grad_fn=<AddBackward0>)
# X = tensor(4.3823, requires_grad=True), f(x) = tensor(46.7918, grad_fn=<AddBackward0>)
# X = tensor(4.3638, requires_grad=True), f(x) = tensor(46.4491, grad_fn=<AddBackward0>)
# X = tensor(4.3453, requires_grad=True), f(x) = tensor(46.1092, grad_fn=<AddBackward0>)
# X = tensor(4.3270, requires_grad=True), f(x) = tensor(45.7720, grad_fn=<AddBackward0>)
# X = tensor(4.3086, requires_grad=True), f(x) = tensor(45.4375, grad_fn=<AddBackward0>)
# X = tensor(4.2904, requires_grad=True), f(x) = tensor(45.1057, grad_fn=<AddBackward0>)
# X = tensor(4.2723, requires_grad=True), f(x) = tensor(44.7765, grad_fn=<AddBackward0>)
# X = tensor(4.2542, requires_grad=True), f(x) = tensor(44.4499, grad_fn=<AddBackward0>)
# X = tensor(4.2361, requires_grad=True), f(x) = tensor(44.1260, grad_fn=<AddBackward0>)
# X = tensor(4.2182, requires_grad=True), f(x) = tensor(43.8046, grad_fn=<AddBackward0>)
# X = tensor(4.2003, requires_grad=True), f(x) = tensor(43.4858, grad_fn=<AddBackward0>)
# X = tensor(4.1825, requires_grad=True), f(x) = tensor(43.1696, grad_fn=<AddBackward0>)
# X = tensor(4.1648, requires_grad=True), f(x) = tensor(42.8558, grad_fn=<AddBackward0>)
# X = tensor(4.1471, requires_grad=True), f(x) = tensor(42.5446, grad_fn=<AddBackward0>)
# X = tensor(4.1295, requires_grad=True), f(x) = tensor(42.2359, grad_fn=<AddBackward0>)
# X = tensor(4.1120, requires_grad=True), f(x) = tensor(41.9296, grad_fn=<AddBackward0>)
# X = tensor(4.0946, requires_grad=True), f(x) = tensor(41.6258, grad_fn=<AddBackward0>)
# X = tensor(4.0772, requires_grad=True), f(x) = tensor(41.3244, grad_fn=<AddBackward0>)
# X = tensor(4.0599, requires_grad=True), f(x) = tensor(41.0254, grad_fn=<AddBackward0>)
# X = tensor(4.0427, requires_grad=True), f(x) = tensor(40.7288, grad_fn=<AddBackward0>)
# X = tensor(4.0255, requires_grad=True), f(x) = tensor(40.4345, grad_fn=<AddBackward0>)
# X = tensor(4.0084, requires_grad=True), f(x) = tensor(40.1427, grad_fn=<AddBackward0>)
# X = tensor(3.9913, requires_grad=True), f(x) = tensor(39.8531, grad_fn=<AddBackward0>)
# X = tensor(3.9744, requires_grad=True), f(x) = tensor(39.5658, grad_fn=<AddBackward0>)
# X = tensor(3.9575, requires_grad=True), f(x) = tensor(39.2809, grad_fn=<AddBackward0>)
# X = tensor(3.9407, requires_grad=True), f(x) = tensor(38.9982, grad_fn=<AddBackward0>)
# X = tensor(3.9239, requires_grad=True), f(x) = tensor(38.7178, grad_fn=<AddBackward0>)
# X = tensor(3.9072, requires_grad=True), f(x) = tensor(38.4396, grad_fn=<AddBackward0>)
# X = tensor(3.8906, requires_grad=True), f(x) = tensor(38.1636, grad_fn=<AddBackward0>)
# X = tensor(3.8740, requires_grad=True), f(x) = tensor(37.8899, grad_fn=<AddBackward0>)
# X = tensor(3.8575, requires_grad=True), f(x) = tensor(37.6183, grad_fn=<AddBackward0>)
# X = tensor(3.8411, requires_grad=True), f(x) = tensor(37.3489, grad_fn=<AddBackward0>)
# X = tensor(3.8247, requires_grad=True), f(x) = tensor(37.0816, grad_fn=<AddBackward0>)
# X = tensor(3.8084, requires_grad=True), f(x) = tensor(36.8165, grad_fn=<AddBackward0>)
# X = tensor(3.7922, requires_grad=True), f(x) = tensor(36.5535, grad_fn=<AddBackward0>)
# X = tensor(3.7760, requires_grad=True), f(x) = tensor(36.2926, grad_fn=<AddBackward0>)
# X = tensor(3.7599, requires_grad=True), f(x) = tensor(36.0338, grad_fn=<AddBackward0>)
# X = tensor(3.7439, requires_grad=True), f(x) = tensor(35.7770, grad_fn=<AddBackward0>)
# X = tensor(3.7279, requires_grad=True), f(x) = tensor(35.5223, grad_fn=<AddBackward0>)
# X = tensor(3.7120, requires_grad=True), f(x) = tensor(35.2697, grad_fn=<AddBackward0>)
# X = tensor(3.6961, requires_grad=True), f(x) = tensor(35.0190, grad_fn=<AddBackward0>)
# X = tensor(3.6804, requires_grad=True), f(x) = tensor(34.7703, grad_fn=<AddBackward0>)
# X = tensor(3.6646, requires_grad=True), f(x) = tensor(34.5237, grad_fn=<AddBackward0>)
# X = tensor(3.6490, requires_grad=True), f(x) = tensor(34.2790, grad_fn=<AddBackward0>)
# X = tensor(3.6334, requires_grad=True), f(x) = tensor(34.0362, grad_fn=<AddBackward0>)
# X = tensor(3.6178, requires_grad=True), f(x) = tensor(33.7954, grad_fn=<AddBackward0>)
# X = tensor(3.6024, requires_grad=True), f(x) = tensor(33.5565, grad_fn=<AddBackward0>)
# X = tensor(3.5870, requires_grad=True), f(x) = tensor(33.3196, grad_fn=<AddBackward0>)
# X = tensor(3.5716, requires_grad=True), f(x) = tensor(33.0845, grad_fn=<AddBackward0>)
# X = tensor(3.5563, requires_grad=True), f(x) = tensor(32.8513, grad_fn=<AddBackward0>)
# X = tensor(3.5411, requires_grad=True), f(x) = tensor(32.6199, grad_fn=<AddBackward0>)
# X = tensor(3.5259, requires_grad=True), f(x) = tensor(32.3904, grad_fn=<AddBackward0>)
# X = tensor(3.5108, requires_grad=True), f(x) = tensor(32.1628, grad_fn=<AddBackward0>)
# X = tensor(3.4958, requires_grad=True), f(x) = tensor(31.9369, grad_fn=<AddBackward0>)
# X = tensor(3.4808, requires_grad=True), f(x) = tensor(31.7129, grad_fn=<AddBackward0>)
# X = tensor(3.4659, requires_grad=True), f(x) = tensor(31.4906, grad_fn=<AddBackward0>)
# X = tensor(3.4510, requires_grad=True), f(x) = tensor(31.2701, grad_fn=<AddBackward0>)
# X = tensor(3.4362, requires_grad=True), f(x) = tensor(31.0514, grad_fn=<AddBackward0>)
# X = tensor(3.4215, requires_grad=True), f(x) = tensor(30.8344, grad_fn=<AddBackward0>)
# X = tensor(3.4068, requires_grad=True), f(x) = tensor(30.6192, grad_fn=<AddBackward0>)
# X = tensor(3.3922, requires_grad=True), f(x) = tensor(30.4057, grad_fn=<AddBackward0>)
# X = tensor(3.3776, requires_grad=True), f(x) = tensor(30.1938, grad_fn=<AddBackward0>)
# X = tensor(3.3631, requires_grad=True), f(x) = tensor(29.9837, grad_fn=<AddBackward0>)
# X = tensor(3.3486, requires_grad=True), f(x) = tensor(29.7753, grad_fn=<AddBackward0>)
# X = tensor(3.3342, requires_grad=True), f(x) = tensor(29.5685, grad_fn=<AddBackward0>)
# X = tensor(3.3199, requires_grad=True), f(x) = tensor(29.3633, grad_fn=<AddBackward0>)
# X = tensor(3.3056, requires_grad=True), f(x) = tensor(29.1598, grad_fn=<AddBackward0>)
# X = tensor(3.2914, requires_grad=True), f(x) = tensor(28.9580, grad_fn=<AddBackward0>)
# X = tensor(3.2772, requires_grad=True), f(x) = tensor(28.7577, grad_fn=<AddBackward0>)
# X = tensor(3.2631, requires_grad=True), f(x) = tensor(28.5590, grad_fn=<AddBackward0>)
# X = tensor(3.2491, requires_grad=True), f(x) = tensor(28.3620, grad_fn=<AddBackward0>)
# X = tensor(3.2351, requires_grad=True), f(x) = tensor(28.1664, grad_fn=<AddBackward0>)
# X = tensor(3.2211, requires_grad=True), f(x) = tensor(27.9725, grad_fn=<AddBackward0>)
# X = tensor(3.2072, requires_grad=True), f(x) = tensor(27.7801, grad_fn=<AddBackward0>)
# X = tensor(3.1934, requires_grad=True), f(x) = tensor(27.5893, grad_fn=<AddBackward0>)
# X = tensor(3.1796, requires_grad=True), f(x) = tensor(27.3999, grad_fn=<AddBackward0>)
# X = tensor(3.1659, requires_grad=True), f(x) = tensor(27.2121, grad_fn=<AddBackward0>)
# X = tensor(3.1523, requires_grad=True), f(x) = tensor(27.0258, grad_fn=<AddBackward0>)
# X = tensor(3.1387, requires_grad=True), f(x) = tensor(26.8409, grad_fn=<AddBackward0>)
# X = tensor(3.1251, requires_grad=True), f(x) = tensor(26.6576, grad_fn=<AddBackward0>)
# X = tensor(3.1116, requires_grad=True), f(x) = tensor(26.4757, grad_fn=<AddBackward0>)
# X = tensor(3.0982, requires_grad=True), f(x) = tensor(26.2952, grad_fn=<AddBackward0>)
# X = tensor(3.0848, requires_grad=True), f(x) = tensor(26.1162, grad_fn=<AddBackward0>)
# X = tensor(3.0714, requires_grad=True), f(x) = tensor(25.9387, grad_fn=<AddBackward0>)
# X = tensor(3.0581, requires_grad=True), f(x) = tensor(25.7625, grad_fn=<AddBackward0>)
# X = tensor(3.0449, requires_grad=True), f(x) = tensor(25.5878, grad_fn=<AddBackward0>)
# X = tensor(3.0317, requires_grad=True), f(x) = tensor(25.4144, grad_fn=<AddBackward0>)
# X = tensor(3.0186, requires_grad=True), f(x) = tensor(25.2424, grad_fn=<AddBackward0>)
# X = tensor(3.0055, requires_grad=True), f(x) = tensor(25.0718, grad_fn=<AddBackward0>)
# X = tensor(2.9925, requires_grad=True), f(x) = tensor(24.9026, grad_fn=<AddBackward0>)
# X = tensor(2.9795, requires_grad=True), f(x) = tensor(24.7347, grad_fn=<AddBackward0>)
# X = tensor(2.9666, requires_grad=True), f(x) = tensor(24.5682, grad_fn=<AddBackward0>)
# X = tensor(2.9537, requires_grad=True), f(x) = tensor(24.4030, grad_fn=<AddBackward0>)
# X = tensor(2.9409, requires_grad=True), f(x) = tensor(24.2391, grad_fn=<AddBackward0>)
# X = tensor(2.9282, requires_grad=True), f(x) = tensor(24.0765, grad_fn=<AddBackward0>)
# X = tensor(2.9155, requires_grad=True), f(x) = tensor(23.9152, grad_fn=<AddBackward0>)
# X = tensor(2.9028, requires_grad=True), f(x) = tensor(23.7552, grad_fn=<AddBackward0>)
# X = tensor(2.8902, requires_grad=True), f(x) = tensor(23.5965, grad_fn=<AddBackward0>)
# X = tensor(2.8776, requires_grad=True), f(x) = tensor(23.4390, grad_fn=<AddBackward0>)
# X = tensor(2.8651, requires_grad=True), f(x) = tensor(23.2828, grad_fn=<AddBackward0>)
# X = tensor(2.8526, requires_grad=True), f(x) = tensor(23.1278, grad_fn=<AddBackward0>)
# X = tensor(2.8402, requires_grad=True), f(x) = tensor(22.9741, grad_fn=<AddBackward0>)
# X = tensor(2.8279, requires_grad=True), f(x) = tensor(22.8216, grad_fn=<AddBackward0>)
# X = tensor(2.8156, requires_grad=True), f(x) = tensor(22.6704, grad_fn=<AddBackward0>)
# X = tensor(2.8033, requires_grad=True), f(x) = tensor(22.5203, grad_fn=<AddBackward0>)
# X = tensor(2.7911, requires_grad=True), f(x) = tensor(22.3714, grad_fn=<AddBackward0>)
# X = tensor(2.7789, requires_grad=True), f(x) = tensor(22.2238, grad_fn=<AddBackward0>)
# X = tensor(2.7668, requires_grad=True), f(x) = tensor(22.0773, grad_fn=<AddBackward0>)
# X = tensor(2.7547, requires_grad=True), f(x) = tensor(21.9319, grad_fn=<AddBackward0>)
# X = tensor(2.7427, requires_grad=True), f(x) = tensor(21.7878, grad_fn=<AddBackward0>)
# X = tensor(2.7308, requires_grad=True), f(x) = tensor(21.6448, grad_fn=<AddBackward0>)
# X = tensor(2.7188, requires_grad=True), f(x) = tensor(21.5029, grad_fn=<AddBackward0>)
# X = tensor(2.7070, requires_grad=True), f(x) = tensor(21.3621, grad_fn=<AddBackward0>)
# X = tensor(2.6951, requires_grad=True), f(x) = tensor(21.2225, grad_fn=<AddBackward0>)
# X = tensor(2.6833, requires_grad=True), f(x) = tensor(21.0840, grad_fn=<AddBackward0>)
# X = tensor(2.6716, requires_grad=True), f(x) = tensor(20.9466, grad_fn=<AddBackward0>)
# X = tensor(2.6599, requires_grad=True), f(x) = tensor(20.8103, grad_fn=<AddBackward0>)
# X = tensor(2.6483, requires_grad=True), f(x) = tensor(20.6751, grad_fn=<AddBackward0>)
# X = tensor(2.6367, requires_grad=True), f(x) = tensor(20.5410, grad_fn=<AddBackward0>)
# X = tensor(2.6251, requires_grad=True), f(x) = tensor(20.4079, grad_fn=<AddBackward0>)
# X = tensor(2.6136, requires_grad=True), f(x) = tensor(20.2759, grad_fn=<AddBackward0>)
# X = tensor(2.6022, requires_grad=True), f(x) = tensor(20.1450, grad_fn=<AddBackward0>)
# X = tensor(2.5908, requires_grad=True), f(x) = tensor(20.0151, grad_fn=<AddBackward0>)
# X = tensor(2.5794, requires_grad=True), f(x) = tensor(19.8862, grad_fn=<AddBackward0>)
# X = tensor(2.5681, requires_grad=True), f(x) = tensor(19.7584, grad_fn=<AddBackward0>)
# X = tensor(2.5568, requires_grad=True), f(x) = tensor(19.6316, grad_fn=<AddBackward0>)
# X = tensor(2.5456, requires_grad=True), f(x) = tensor(19.5058, grad_fn=<AddBackward0>)
# X = tensor(2.5344, requires_grad=True), f(x) = tensor(19.3810, grad_fn=<AddBackward0>)
# X = tensor(2.5233, requires_grad=True), f(x) = tensor(19.2572, grad_fn=<AddBackward0>)
# X = tensor(2.5122, requires_grad=True), f(x) = tensor(19.1344, grad_fn=<AddBackward0>)
# X = tensor(2.5011, requires_grad=True), f(x) = tensor(19.0125, grad_fn=<AddBackward0>)
# X = tensor(2.4901, requires_grad=True), f(x) = tensor(18.8917, grad_fn=<AddBackward0>)
# X = tensor(2.4792, requires_grad=True), f(x) = tensor(18.7718, grad_fn=<AddBackward0>)
# X = tensor(2.4683, requires_grad=True), f(x) = tensor(18.6529, grad_fn=<AddBackward0>)
# X = tensor(2.4574, requires_grad=True), f(x) = tensor(18.5349, grad_fn=<AddBackward0>)
# X = tensor(2.4466, requires_grad=True), f(x) = tensor(18.4178, grad_fn=<AddBackward0>)
# X = tensor(2.4358, requires_grad=True), f(x) = tensor(18.3017, grad_fn=<AddBackward0>)
# X = tensor(2.4250, requires_grad=True), f(x) = tensor(18.1865, grad_fn=<AddBackward0>)
# X = tensor(2.4143, requires_grad=True), f(x) = tensor(18.0723, grad_fn=<AddBackward0>)
# X = tensor(2.4037, requires_grad=True), f(x) = tensor(17.9589, grad_fn=<AddBackward0>)
# X = tensor(2.3931, requires_grad=True), f(x) = tensor(17.8465, grad_fn=<AddBackward0>)
# X = tensor(2.3825, requires_grad=True), f(x) = tensor(17.7349, grad_fn=<AddBackward0>)
# X = tensor(2.3720, requires_grad=True), f(x) = tensor(17.6243, grad_fn=<AddBackward0>)
# X = tensor(2.3615, requires_grad=True), f(x) = tensor(17.5145, grad_fn=<AddBackward0>)
# X = tensor(2.3510, requires_grad=True), f(x) = tensor(17.4056, grad_fn=<AddBackward0>)
# X = tensor(2.3406, requires_grad=True), f(x) = tensor(17.2976, grad_fn=<AddBackward0>)
# X = tensor(2.3303, requires_grad=True), f(x) = tensor(17.1904, grad_fn=<AddBackward0>)
# X = tensor(2.3199, requires_grad=True), f(x) = tensor(17.0841, grad_fn=<AddBackward0>)
# X = tensor(2.3097, requires_grad=True), f(x) = tensor(16.9786, grad_fn=<AddBackward0>)
# X = tensor(2.2994, requires_grad=True), f(x) = tensor(16.8740, grad_fn=<AddBackward0>)
# X = tensor(2.2892, requires_grad=True), f(x) = tensor(16.7702, grad_fn=<AddBackward0>)
# X = tensor(2.2791, requires_grad=True), f(x) = tensor(16.6673, grad_fn=<AddBackward0>)
# X = tensor(2.2689, requires_grad=True), f(x) = tensor(16.5651, grad_fn=<AddBackward0>)
# X = tensor(2.2589, requires_grad=True), f(x) = tensor(16.4638, grad_fn=<AddBackward0>)
# X = tensor(2.2488, requires_grad=True), f(x) = tensor(16.3633, grad_fn=<AddBackward0>)
# X = tensor(2.2388, requires_grad=True), f(x) = tensor(16.2636, grad_fn=<AddBackward0>)
# X = tensor(2.2289, requires_grad=True), f(x) = tensor(16.1647, grad_fn=<AddBackward0>)
# X = tensor(2.2190, requires_grad=True), f(x) = tensor(16.0666, grad_fn=<AddBackward0>)
# X = tensor(2.2091, requires_grad=True), f(x) = tensor(15.9692, grad_fn=<AddBackward0>)
# X = tensor(2.1993, requires_grad=True), f(x) = tensor(15.8727, grad_fn=<AddBackward0>)
# X = tensor(2.1895, requires_grad=True), f(x) = tensor(15.7769, grad_fn=<AddBackward0>)
# X = tensor(2.1797, requires_grad=True), f(x) = tensor(15.6819, grad_fn=<AddBackward0>)
# X = tensor(2.1700, requires_grad=True), f(x) = tensor(15.5876, grad_fn=<AddBackward0>)
# X = tensor(2.1603, requires_grad=True), f(x) = tensor(15.4941, grad_fn=<AddBackward0>)
# X = tensor(2.1507, requires_grad=True), f(x) = tensor(15.4013, grad_fn=<AddBackward0>)
# X = tensor(2.1411, requires_grad=True), f(x) = tensor(15.3093, grad_fn=<AddBackward0>)
# X = tensor(2.1315, requires_grad=True), f(x) = tensor(15.2180, grad_fn=<AddBackward0>)
# X = tensor(2.1220, requires_grad=True), f(x) = tensor(15.1274, grad_fn=<AddBackward0>)
# X = tensor(2.1125, requires_grad=True), f(x) = tensor(15.0376, grad_fn=<AddBackward0>)
# X = tensor(2.1030, requires_grad=True), f(x) = tensor(14.9485, grad_fn=<AddBackward0>)
# X = tensor(2.0936, requires_grad=True), f(x) = tensor(14.8601, grad_fn=<AddBackward0>)
# X = tensor(2.0842, requires_grad=True), f(x) = tensor(14.7724, grad_fn=<AddBackward0>)
# X = tensor(2.0749, requires_grad=True), f(x) = tensor(14.6853, grad_fn=<AddBackward0>)
# X = tensor(2.0656, requires_grad=True), f(x) = tensor(14.5990, grad_fn=<AddBackward0>)
# X = tensor(2.0563, requires_grad=True), f(x) = tensor(14.5134, grad_fn=<AddBackward0>)
# X = tensor(2.0471, requires_grad=True), f(x) = tensor(14.4285, grad_fn=<AddBackward0>)
# X = tensor(2.0379, requires_grad=True), f(x) = tensor(14.3442, grad_fn=<AddBackward0>)
# X = tensor(2.0288, requires_grad=True), f(x) = tensor(14.2606, grad_fn=<AddBackward0>)
# X = tensor(2.0197, requires_grad=True), f(x) = tensor(14.1777, grad_fn=<AddBackward0>)
# X = tensor(2.0106, requires_grad=True), f(x) = tensor(14.0955, grad_fn=<AddBackward0>)
# X = tensor(2.0015, requires_grad=True), f(x) = tensor(14.0139, grad_fn=<AddBackward0>)
# X = tensor(1.9925, requires_grad=True), f(x) = tensor(13.9329, grad_fn=<AddBackward0>)
# X = tensor(1.9836, requires_grad=True), f(x) = tensor(13.8526, grad_fn=<AddBackward0>)
# X = tensor(1.9746, requires_grad=True), f(x) = tensor(13.7729, grad_fn=<AddBackward0>)
# X = tensor(1.9657, requires_grad=True), f(x) = tensor(13.6939, grad_fn=<AddBackward0>)
# X = tensor(1.9569, requires_grad=True), f(x) = tensor(13.6155, grad_fn=<AddBackward0>)
# X = tensor(1.9480, requires_grad=True), f(x) = tensor(13.5378, grad_fn=<AddBackward0>)
# X = tensor(1.9392, requires_grad=True), f(x) = tensor(13.4606, grad_fn=<AddBackward0>)
# X = tensor(1.9305, requires_grad=True), f(x) = tensor(13.3841, grad_fn=<AddBackward0>)
# X = tensor(1.9218, requires_grad=True), f(x) = tensor(13.3082, grad_fn=<AddBackward0>)
# X = tensor(1.9131, requires_grad=True), f(x) = tensor(13.2328, grad_fn=<AddBackward0>)
# X = tensor(1.9044, requires_grad=True), f(x) = tensor(13.1581, grad_fn=<AddBackward0>)
# X = tensor(1.8958, requires_grad=True), f(x) = tensor(13.0840, grad_fn=<AddBackward0>)
# X = tensor(1.8872, requires_grad=True), f(x) = tensor(13.0105, grad_fn=<AddBackward0>)
# X = tensor(1.8787, requires_grad=True), f(x) = tensor(12.9376, grad_fn=<AddBackward0>)
# X = tensor(1.8702, requires_grad=True), f(x) = tensor(12.8652, grad_fn=<AddBackward0>)
# X = tensor(1.8617, requires_grad=True), f(x) = tensor(12.7934, grad_fn=<AddBackward0>)
# X = tensor(1.8532, requires_grad=True), f(x) = tensor(12.7222, grad_fn=<AddBackward0>)
# X = tensor(1.8448, requires_grad=True), f(x) = tensor(12.6516, grad_fn=<AddBackward0>)
# X = tensor(1.8364, requires_grad=True), f(x) = tensor(12.5815, grad_fn=<AddBackward0>)
# X = tensor(1.8281, requires_grad=True), f(x) = tensor(12.5120, grad_fn=<AddBackward0>)
# X = tensor(1.8198, requires_grad=True), f(x) = tensor(12.4430, grad_fn=<AddBackward0>)
# X = tensor(1.8115, requires_grad=True), f(x) = tensor(12.3746, grad_fn=<AddBackward0>)
# X = tensor(1.8033, requires_grad=True), f(x) = tensor(12.3068, grad_fn=<AddBackward0>)
# X = tensor(1.7950, requires_grad=True), f(x) = tensor(12.2395, grad_fn=<AddBackward0>)
# X = tensor(1.7869, requires_grad=True), f(x) = tensor(12.1727, grad_fn=<AddBackward0>)
# X = tensor(1.7787, requires_grad=True), f(x) = tensor(12.1064, grad_fn=<AddBackward0>)
# X = tensor(1.7706, requires_grad=True), f(x) = tensor(12.0407, grad_fn=<AddBackward0>)
# X = tensor(1.7625, requires_grad=True), f(x) = tensor(11.9755, grad_fn=<AddBackward0>)
# X = tensor(1.7545, requires_grad=True), f(x) = tensor(11.9108, grad_fn=<AddBackward0>)
# X = tensor(1.7465, requires_grad=True), f(x) = tensor(11.8467, grad_fn=<AddBackward0>)
# X = tensor(1.7385, requires_grad=True), f(x) = tensor(11.7830, grad_fn=<AddBackward0>)
# X = tensor(1.7305, requires_grad=True), f(x) = tensor(11.7199, grad_fn=<AddBackward0>)
# X = tensor(1.7226, requires_grad=True), f(x) = tensor(11.6573, grad_fn=<AddBackward0>)
# X = tensor(1.7147, requires_grad=True), f(x) = tensor(11.5951, grad_fn=<AddBackward0>)
# X = tensor(1.7068, requires_grad=True), f(x) = tensor(11.5335, grad_fn=<AddBackward0>)
# X = tensor(1.6990, requires_grad=True), f(x) = tensor(11.4723, grad_fn=<AddBackward0>)
# X = tensor(1.6912, requires_grad=True), f(x) = tensor(11.4117, grad_fn=<AddBackward0>)
# X = tensor(1.6835, requires_grad=True), f(x) = tensor(11.3515, grad_fn=<AddBackward0>)
# X = tensor(1.6757, requires_grad=True), f(x) = tensor(11.2918, grad_fn=<AddBackward0>)
# X = tensor(1.6680, requires_grad=True), f(x) = tensor(11.2326, grad_fn=<AddBackward0>)
# X = tensor(1.6603, requires_grad=True), f(x) = tensor(11.1739, grad_fn=<AddBackward0>)
# X = tensor(1.6527, requires_grad=True), f(x) = tensor(11.1156, grad_fn=<AddBackward0>)
# X = tensor(1.6451, requires_grad=True), f(x) = tensor(11.0578, grad_fn=<AddBackward0>)
# X = tensor(1.6375, requires_grad=True), f(x) = tensor(11.0004, grad_fn=<AddBackward0>)
# X = tensor(1.6300, requires_grad=True), f(x) = tensor(10.9435, grad_fn=<AddBackward0>)
# X = tensor(1.6224, requires_grad=True), f(x) = tensor(10.8871, grad_fn=<AddBackward0>)
# X = tensor(1.6150, requires_grad=True), f(x) = tensor(10.8311, grad_fn=<AddBackward0>)
# X = tensor(1.6075, requires_grad=True), f(x) = tensor(10.7756, grad_fn=<AddBackward0>)
# X = tensor(1.6001, requires_grad=True), f(x) = tensor(10.7205, grad_fn=<AddBackward0>)
# X = tensor(1.5927, requires_grad=True), f(x) = tensor(10.6658, grad_fn=<AddBackward0>)
# X = tensor(1.5853, requires_grad=True), f(x) = tensor(10.6116, grad_fn=<AddBackward0>)
# X = tensor(1.5780, requires_grad=True), f(x) = tensor(10.5578, grad_fn=<AddBackward0>)
# X = tensor(1.5706, requires_grad=True), f(x) = tensor(10.5045, grad_fn=<AddBackward0>)
# X = tensor(1.5634, requires_grad=True), f(x) = tensor(10.4515, grad_fn=<AddBackward0>)
# X = tensor(1.5561, requires_grad=True), f(x) = tensor(10.3990, grad_fn=<AddBackward0>)
# X = tensor(1.5489, requires_grad=True), f(x) = tensor(10.3469, grad_fn=<AddBackward0>)
# X = tensor(1.5417, requires_grad=True), f(x) = tensor(10.2953, grad_fn=<AddBackward0>)
# X = tensor(1.5345, requires_grad=True), f(x) = tensor(10.2440, grad_fn=<AddBackward0>)
# X = tensor(1.5274, requires_grad=True), f(x) = tensor(10.1932, grad_fn=<AddBackward0>)
# X = tensor(1.5203, requires_grad=True), f(x) = tensor(10.1427, grad_fn=<AddBackward0>)
# X = tensor(1.5132, requires_grad=True), f(x) = tensor(10.0927, grad_fn=<AddBackward0>)
# X = tensor(1.5061, requires_grad=True), f(x) = tensor(10.0430, grad_fn=<AddBackward0>)
# X = tensor(1.4991, requires_grad=True), f(x) = tensor(9.9938, grad_fn=<AddBackward0>)
# X = tensor(1.4921, requires_grad=True), f(x) = tensor(9.9449, grad_fn=<AddBackward0>)
# X = tensor(1.4851, requires_grad=True), f(x) = tensor(9.8965, grad_fn=<AddBackward0>)
# X = tensor(1.4782, requires_grad=True), f(x) = tensor(9.8484, grad_fn=<AddBackward0>)
# X = tensor(1.4713, requires_grad=True), f(x) = tensor(9.8007, grad_fn=<AddBackward0>)
# X = tensor(1.4644, requires_grad=True), f(x) = tensor(9.7534, grad_fn=<AddBackward0>)
# X = tensor(1.4576, requires_grad=True), f(x) = tensor(9.7065, grad_fn=<AddBackward0>)
# X = tensor(1.4507, requires_grad=True), f(x) = tensor(9.6599, grad_fn=<AddBackward0>)
# X = tensor(1.4439, requires_grad=True), f(x) = tensor(9.6137, grad_fn=<AddBackward0>)
# X = tensor(1.4371, requires_grad=True), f(x) = tensor(9.5679, grad_fn=<AddBackward0>)
# X = tensor(1.4304, requires_grad=True), f(x) = tensor(9.5225, grad_fn=<AddBackward0>)
# X = tensor(1.4237, requires_grad=True), f(x) = tensor(9.4774, grad_fn=<AddBackward0>)
# X = tensor(1.4170, requires_grad=True), f(x) = tensor(9.4326, grad_fn=<AddBackward0>)
# X = tensor(1.4103, requires_grad=True), f(x) = tensor(9.3883, grad_fn=<AddBackward0>)
# X = tensor(1.4037, requires_grad=True), f(x) = tensor(9.3442, grad_fn=<AddBackward0>)
# X = tensor(1.3971, requires_grad=True), f(x) = tensor(9.3006, grad_fn=<AddBackward0>)
# X = tensor(1.3905, requires_grad=True), f(x) = tensor(9.2573, grad_fn=<AddBackward0>)
# X = tensor(1.3839, requires_grad=True), f(x) = tensor(9.2143, grad_fn=<AddBackward0>)
# X = tensor(1.3774, requires_grad=True), f(x) = tensor(9.1717, grad_fn=<AddBackward0>)
# X = tensor(1.3709, requires_grad=True), f(x) = tensor(9.1294, grad_fn=<AddBackward0>)
# X = tensor(1.3644, requires_grad=True), f(x) = tensor(9.0874, grad_fn=<AddBackward0>)
# X = tensor(1.3579, requires_grad=True), f(x) = tensor(9.0458, grad_fn=<AddBackward0>)
# X = tensor(1.3515, requires_grad=True), f(x) = tensor(9.0045, grad_fn=<AddBackward0>)
# X = tensor(1.3451, requires_grad=True), f(x) = tensor(8.9636, grad_fn=<AddBackward0>)
# X = tensor(1.3387, requires_grad=True), f(x) = tensor(8.9229, grad_fn=<AddBackward0>)
# X = tensor(1.3323, requires_grad=True), f(x) = tensor(8.8826, grad_fn=<AddBackward0>)
# X = tensor(1.3260, requires_grad=True), f(x) = tensor(8.8427, grad_fn=<AddBackward0>)
# X = tensor(1.3197, requires_grad=True), f(x) = tensor(8.8030, grad_fn=<AddBackward0>)
# X = tensor(1.3134, requires_grad=True), f(x) = tensor(8.7636, grad_fn=<AddBackward0>)
# X = tensor(1.3072, requires_grad=True), f(x) = tensor(8.7246, grad_fn=<AddBackward0>)
# X = tensor(1.3010, requires_grad=True), f(x) = tensor(8.6859, grad_fn=<AddBackward0>)
# X = tensor(1.2947, requires_grad=True), f(x) = tensor(8.6475, grad_fn=<AddBackward0>)
# X = tensor(1.2886, requires_grad=True), f(x) = tensor(8.6094, grad_fn=<AddBackward0>)
# X = tensor(1.2824, requires_grad=True), f(x) = tensor(8.5716, grad_fn=<AddBackward0>)
# X = tensor(1.2763, requires_grad=True), f(x) = tensor(8.5341, grad_fn=<AddBackward0>)
# X = tensor(1.2702, requires_grad=True), f(x) = tensor(8.4969, grad_fn=<AddBackward0>)
# X = tensor(1.2641, requires_grad=True), f(x) = tensor(8.4600, grad_fn=<AddBackward0>)
# X = tensor(1.2580, requires_grad=True), f(x) = tensor(8.4234, grad_fn=<AddBackward0>)
# X = tensor(1.2520, requires_grad=True), f(x) = tensor(8.3871, grad_fn=<AddBackward0>)
# X = tensor(1.2460, requires_grad=True), f(x) = tensor(8.3510, grad_fn=<AddBackward0>)
# X = tensor(1.2400, requires_grad=True), f(x) = tensor(8.3153, grad_fn=<AddBackward0>)
# X = tensor(1.2341, requires_grad=True), f(x) = tensor(8.2799, grad_fn=<AddBackward0>)
# X = tensor(1.2281, requires_grad=True), f(x) = tensor(8.2447, grad_fn=<AddBackward0>)
# X = tensor(1.2222, requires_grad=True), f(x) = tensor(8.2098, grad_fn=<AddBackward0>)
# X = tensor(1.2163, requires_grad=True), f(x) = tensor(8.1752, grad_fn=<AddBackward0>)
# X = tensor(1.2105, requires_grad=True), f(x) = tensor(8.1409, grad_fn=<AddBackward0>)
# X = tensor(1.2046, requires_grad=True), f(x) = tensor(8.1068, grad_fn=<AddBackward0>)
# X = tensor(1.1988, requires_grad=True), f(x) = tensor(8.0730, grad_fn=<AddBackward0>)
# X = tensor(1.1930, requires_grad=True), f(x) = tensor(8.0395, grad_fn=<AddBackward0>)
# X = tensor(1.1872, requires_grad=True), f(x) = tensor(8.0062, grad_fn=<AddBackward0>)
# X = tensor(1.1815, requires_grad=True), f(x) = tensor(7.9733, grad_fn=<AddBackward0>)
# X = tensor(1.1758, requires_grad=True), f(x) = tensor(7.9405, grad_fn=<AddBackward0>)
# X = tensor(1.1700, requires_grad=True), f(x) = tensor(7.9081, grad_fn=<AddBackward0>)
# X = tensor(1.1644, requires_grad=True), f(x) = tensor(7.8759, grad_fn=<AddBackward0>)
# X = tensor(1.1587, requires_grad=True), f(x) = tensor(7.8439, grad_fn=<AddBackward0>)
# X = tensor(1.1531, requires_grad=True), f(x) = tensor(7.8122, grad_fn=<AddBackward0>)
# X = tensor(1.1475, requires_grad=True), f(x) = tensor(7.7808, grad_fn=<AddBackward0>)
# X = tensor(1.1419, requires_grad=True), f(x) = tensor(7.7496, grad_fn=<AddBackward0>)
# X = tensor(1.1363, requires_grad=True), f(x) = tensor(7.7187, grad_fn=<AddBackward0>)
# X = tensor(1.1308, requires_grad=True), f(x) = tensor(7.6880, grad_fn=<AddBackward0>)
# X = tensor(1.1252, requires_grad=True), f(x) = tensor(7.6576, grad_fn=<AddBackward0>)
# X = tensor(1.1197, requires_grad=True), f(x) = tensor(7.6274, grad_fn=<AddBackward0>)
# X = tensor(1.1143, requires_grad=True), f(x) = tensor(7.5974, grad_fn=<AddBackward0>)
# X = tensor(1.1088, requires_grad=True), f(x) = tensor(7.5677, grad_fn=<AddBackward0>)
# X = tensor(1.1034, requires_grad=True), f(x) = tensor(7.5382, grad_fn=<AddBackward0>)
# X = tensor(1.0980, requires_grad=True), f(x) = tensor(7.5090, grad_fn=<AddBackward0>)
# X = tensor(1.0926, requires_grad=True), f(x) = tensor(7.4799, grad_fn=<AddBackward0>)
# X = tensor(1.0872, requires_grad=True), f(x) = tensor(7.4512, grad_fn=<AddBackward0>)
# X = tensor(1.0818, requires_grad=True), f(x) = tensor(7.4226, grad_fn=<AddBackward0>)
# X = tensor(1.0765, requires_grad=True), f(x) = tensor(7.3943, grad_fn=<AddBackward0>)
# X = tensor(1.0712, requires_grad=True), f(x) = tensor(7.3662, grad_fn=<AddBackward0>)
# X = tensor(1.0659, requires_grad=True), f(x) = tensor(7.3383, grad_fn=<AddBackward0>)
# X = tensor(1.0607, requires_grad=True), f(x) = tensor(7.3107, grad_fn=<AddBackward0>)
# X = tensor(1.0554, requires_grad=True), f(x) = tensor(7.2832, grad_fn=<AddBackward0>)
# X = tensor(1.0502, requires_grad=True), f(x) = tensor(7.2560, grad_fn=<AddBackward0>)
# X = tensor(1.0450, requires_grad=True), f(x) = tensor(7.2290, grad_fn=<AddBackward0>)
# X = tensor(1.0398, requires_grad=True), f(x) = tensor(7.2022, grad_fn=<AddBackward0>)
# X = tensor(1.0347, requires_grad=True), f(x) = tensor(7.1757, grad_fn=<AddBackward0>)
# X = tensor(1.0295, requires_grad=True), f(x) = tensor(7.1493, grad_fn=<AddBackward0>)
# X = tensor(1.0244, requires_grad=True), f(x) = tensor(7.1232, grad_fn=<AddBackward0>)
# X = tensor(1.0193, requires_grad=True), f(x) = tensor(7.0973, grad_fn=<AddBackward0>)
# X = tensor(1.0142, requires_grad=True), f(x) = tensor(7.0715, grad_fn=<AddBackward0>)
# X = tensor(1.0092, requires_grad=True), f(x) = tensor(7.0460, grad_fn=<AddBackward0>)
# X = tensor(1.0041, requires_grad=True), f(x) = tensor(7.0207, grad_fn=<AddBackward0>)
# X = tensor(0.9991, requires_grad=True), f(x) = tensor(6.9956, grad_fn=<AddBackward0>)
# X = tensor(0.9941, requires_grad=True), f(x) = tensor(6.9707, grad_fn=<AddBackward0>)
# X = tensor(0.9891, requires_grad=True), f(x) = tensor(6.9459, grad_fn=<AddBackward0>)
# X = tensor(0.9842, requires_grad=True), f(x) = tensor(6.9214, grad_fn=<AddBackward0>)
# X = tensor(0.9792, requires_grad=True), f(x) = tensor(6.8971, grad_fn=<AddBackward0>)
# X = tensor(0.9743, requires_grad=True), f(x) = tensor(6.8730, grad_fn=<AddBackward0>)
# X = tensor(0.9694, requires_grad=True), f(x) = tensor(6.8490, grad_fn=<AddBackward0>)
# X = tensor(0.9646, requires_grad=True), f(x) = tensor(6.8253, grad_fn=<AddBackward0>)
# X = tensor(0.9597, requires_grad=True), f(x) = tensor(6.8017, grad_fn=<AddBackward0>)
# X = tensor(0.9549, requires_grad=True), f(x) = tensor(6.7784, grad_fn=<AddBackward0>)
# X = tensor(0.9500, requires_grad=True), f(x) = tensor(6.7552, grad_fn=<AddBackward0>)
# X = tensor(0.9452, requires_grad=True), f(x) = tensor(6.7322, grad_fn=<AddBackward0>)
# X = tensor(0.9405, requires_grad=True), f(x) = tensor(6.7094, grad_fn=<AddBackward0>)
# X = tensor(0.9357, requires_grad=True), f(x) = tensor(6.6868, grad_fn=<AddBackward0>)
# X = tensor(0.9310, requires_grad=True), f(x) = tensor(6.6643, grad_fn=<AddBackward0>)
# X = tensor(0.9262, requires_grad=True), f(x) = tensor(6.6420, grad_fn=<AddBackward0>)
# X = tensor(0.9215, requires_grad=True), f(x) = tensor(6.6199, grad_fn=<AddBackward0>)
# X = tensor(0.9168, requires_grad=True), f(x) = tensor(6.5980, grad_fn=<AddBackward0>)
# X = tensor(0.9122, requires_grad=True), f(x) = tensor(6.5763, grad_fn=<AddBackward0>)
# X = tensor(0.9075, requires_grad=True), f(x) = tensor(6.5547, grad_fn=<AddBackward0>)
# X = tensor(0.9029, requires_grad=True), f(x) = tensor(6.5333, grad_fn=<AddBackward0>)
# X = tensor(0.8983, requires_grad=True), f(x) = tensor(6.5121, grad_fn=<AddBackward0>)
# X = tensor(0.8937, requires_grad=True), f(x) = tensor(6.4910, grad_fn=<AddBackward0>)
# X = tensor(0.8891, requires_grad=True), f(x) = tensor(6.4702, grad_fn=<AddBackward0>)
# X = tensor(0.8846, requires_grad=True), f(x) = tensor(6.4494, grad_fn=<AddBackward0>)
# X = tensor(0.8800, requires_grad=True), f(x) = tensor(6.4289, grad_fn=<AddBackward0>)
# X = tensor(0.8755, requires_grad=True), f(x) = tensor(6.4085, grad_fn=<AddBackward0>)
# X = tensor(0.8710, requires_grad=True), f(x) = tensor(6.3883, grad_fn=<AddBackward0>)
# X = tensor(0.8665, requires_grad=True), f(x) = tensor(6.3682, grad_fn=<AddBackward0>)
# X = tensor(0.8620, requires_grad=True), f(x) = tensor(6.3483, grad_fn=<AddBackward0>)
# X = tensor(0.8576, requires_grad=True), f(x) = tensor(6.3286, grad_fn=<AddBackward0>)
# X = tensor(0.8532, requires_grad=True), f(x) = tensor(6.3090, grad_fn=<AddBackward0>)
# X = tensor(0.8488, requires_grad=True), f(x) = tensor(6.2895, grad_fn=<AddBackward0>)
# X = tensor(0.8444, requires_grad=True), f(x) = tensor(6.2703, grad_fn=<AddBackward0>)
# X = tensor(0.8400, requires_grad=True), f(x) = tensor(6.2511, grad_fn=<AddBackward0>)
# X = tensor(0.8356, requires_grad=True), f(x) = tensor(6.2322, grad_fn=<AddBackward0>)
# X = tensor(0.8313, requires_grad=True), f(x) = tensor(6.2133, grad_fn=<AddBackward0>)
# X = tensor(0.8270, requires_grad=True), f(x) = tensor(6.1947, grad_fn=<AddBackward0>)
# X = tensor(0.8226, requires_grad=True), f(x) = tensor(6.1761, grad_fn=<AddBackward0>)
# X = tensor(0.8184, requires_grad=True), f(x) = tensor(6.1578, grad_fn=<AddBackward0>)
# X = tensor(0.8141, requires_grad=True), f(x) = tensor(6.1395, grad_fn=<AddBackward0>)
# X = tensor(0.8098, requires_grad=True), f(x) = tensor(6.1215, grad_fn=<AddBackward0>)
# X = tensor(0.8056, requires_grad=True), f(x) = tensor(6.1035, grad_fn=<AddBackward0>)
# X = tensor(0.8014, requires_grad=True), f(x) = tensor(6.0857, grad_fn=<AddBackward0>)
# X = tensor(0.7972, requires_grad=True), f(x) = tensor(6.0681, grad_fn=<AddBackward0>)
# X = tensor(0.7930, requires_grad=True), f(x) = tensor(6.0506, grad_fn=<AddBackward0>)
# X = tensor(0.7888, requires_grad=True), f(x) = tensor(6.0332, grad_fn=<AddBackward0>)
# X = tensor(0.7846, requires_grad=True), f(x) = tensor(6.0160, grad_fn=<AddBackward0>)
# X = tensor(0.7805, requires_grad=True), f(x) = tensor(5.9989, grad_fn=<AddBackward0>)
# X = tensor(0.7764, requires_grad=True), f(x) = tensor(5.9819, grad_fn=<AddBackward0>)
# X = tensor(0.7723, requires_grad=True), f(x) = tensor(5.9651, grad_fn=<AddBackward0>)
# X = tensor(0.7682, requires_grad=True), f(x) = tensor(5.9484, grad_fn=<AddBackward0>)
# X = tensor(0.7641, requires_grad=True), f(x) = tensor(5.9319, grad_fn=<AddBackward0>)
# X = tensor(0.7601, requires_grad=True), f(x) = tensor(5.9154, grad_fn=<AddBackward0>)
# X = tensor(0.7560, requires_grad=True), f(x) = tensor(5.8992, grad_fn=<AddBackward0>)
# X = tensor(0.7520, requires_grad=True), f(x) = tensor(5.8830, grad_fn=<AddBackward0>)
# X = tensor(0.7480, requires_grad=True), f(x) = tensor(5.8670, grad_fn=<AddBackward0>)
# X = tensor(0.7440, requires_grad=True), f(x) = tensor(5.8511, grad_fn=<AddBackward0>)
# X = tensor(0.7400, requires_grad=True), f(x) = tensor(5.8353, grad_fn=<AddBackward0>)
# X = tensor(0.7361, requires_grad=True), f(x) = tensor(5.8196, grad_fn=<AddBackward0>)
# X = tensor(0.7321, requires_grad=True), f(x) = tensor(5.8041, grad_fn=<AddBackward0>)
# X = tensor(0.7282, requires_grad=True), f(x) = tensor(5.7887, grad_fn=<AddBackward0>)
# X = tensor(0.7243, requires_grad=True), f(x) = tensor(5.7734, grad_fn=<AddBackward0>)
# X = tensor(0.7204, requires_grad=True), f(x) = tensor(5.7583, grad_fn=<AddBackward0>)
# X = tensor(0.7165, requires_grad=True), f(x) = tensor(5.7432, grad_fn=<AddBackward0>)
# X = tensor(0.7126, requires_grad=True), f(x) = tensor(5.7283, grad_fn=<AddBackward0>)
# X = tensor(0.7088, requires_grad=True), f(x) = tensor(5.7135, grad_fn=<AddBackward0>)
# X = tensor(0.7049, requires_grad=True), f(x) = tensor(5.6988, grad_fn=<AddBackward0>)
# X = tensor(0.7011, requires_grad=True), f(x) = tensor(5.6843, grad_fn=<AddBackward0>)
# X = tensor(0.6973, requires_grad=True), f(x) = tensor(5.6698, grad_fn=<AddBackward0>)
# X = tensor(0.6935, requires_grad=True), f(x) = tensor(5.6555, grad_fn=<AddBackward0>)
# X = tensor(0.6898, requires_grad=True), f(x) = tensor(5.6413, grad_fn=<AddBackward0>)
# X = tensor(0.6860, requires_grad=True), f(x) = tensor(5.6272, grad_fn=<AddBackward0>)
# X = tensor(0.6823, requires_grad=True), f(x) = tensor(5.6132, grad_fn=<AddBackward0>)
# X = tensor(0.6785, requires_grad=True), f(x) = tensor(5.5993, grad_fn=<AddBackward0>)
# X = tensor(0.6748, requires_grad=True), f(x) = tensor(5.5855, grad_fn=<AddBackward0>)
# X = tensor(0.6711, requires_grad=True), f(x) = tensor(5.5719, grad_fn=<AddBackward0>)
# X = tensor(0.6674, requires_grad=True), f(x) = tensor(5.5583, grad_fn=<AddBackward0>)
# X = tensor(0.6638, requires_grad=True), f(x) = tensor(5.5449, grad_fn=<AddBackward0>)
# X = tensor(0.6601, requires_grad=True), f(x) = tensor(5.5316, grad_fn=<AddBackward0>)
# X = tensor(0.6565, requires_grad=True), f(x) = tensor(5.5183, grad_fn=<AddBackward0>)
# X = tensor(0.6528, requires_grad=True), f(x) = tensor(5.5052, grad_fn=<AddBackward0>)
# ...
# X = tensor(-0.2443, requires_grad=True), f(x) = tensor(3.8751, grad_fn=<AddBackward0>)
# X = tensor(-0.2444, requires_grad=True), f(x) = tensor(3.8751, grad_fn=<AddBackward0>)
# X = tensor(-0.2444, requires_grad=True), f(x) = tensor(3.8751, grad_fn=<AddBackward0>)
# X = tensor(-0.2444, requires_grad=True), f(x) = tensor(3.8751, grad_fn=<AddBackward0>)
# X = tensor(-0.2444, requires_grad=True), f(x) = tensor(3.8751, grad_fn=<AddBackward0>)
# X = tensor(-0.2444, requires_grad=True), f(x) = tensor(3.8751, grad_fn=<AddBackward0>)
# X = tensor(-0.2445, requires_grad=True), f(x) = tensor(3.8751, grad_fn=<AddBackward0>)
# X = tensor(-0.2445, requires_grad=True), f(x) = tensor(3.8751, grad_fn=<AddBackward0>)
# X = tensor(-0.2445, requires_grad=True), f(x) = tensor(3.8751, grad_fn=<AddBackward0>)
# X = tensor(-0.2445, requires_grad=True), f(x) = tensor(3.8751, grad_fn=<AddBackward0>)
# X = tensor(-0.2446, requires_grad=True), f(x) = tensor(3.8751, grad_fn=<AddBackward0>)
# X = tensor(-0.2446, requires_grad=True), f(x) = tensor(3.8751, grad_fn=<AddBackward0>)
# X = tensor(-0.2446, requires_grad=True), f(x) = tensor(3.8751, grad_fn=<AddBackward0>)
# X = tensor(-0.2446, requires_grad=True), f(x) = tensor(3.8751, grad_fn=<AddBackward0>)
# X = tensor(-0.2446, requires_grad=True), f(x) = tensor(3.8751, grad_fn=<AddBackward0>)
# X = tensor(-0.2447, requires_grad=True), f(x) = tensor(3.8751, grad_fn=<AddBackward0>)
# X = tensor(-0.2447, requires_grad=True), f(x) = tensor(3.8751, grad_fn=<AddBackward0>)
# X = tensor(-0.2447, requires_grad=True), f(x) = tensor(3.8751, grad_fn=<AddBackward0>)
# X = tensor(-0.2447, requires_grad=True), f(x) = tensor(3.8751, grad_fn=<AddBackward0>)
# X = tensor(-0.2447, requires_grad=True), f(x) = tensor(3.8751, grad_fn=<AddBackward0>)
# X = tensor(-0.2448, requires_grad=True), f(x) = tensor(3.8751, grad_fn=<AddBackward0>)
# X = tensor(-0.2448, requires_grad=True), f(x) = tensor(3.8751, grad_fn=<AddBackward0>)
# X = tensor(-0.2448, requires_grad=True), f(x) = tensor(3.8751, grad_fn=<AddBackward0>)
# X = tensor(-0.2448, requires_grad=True), f(x) = tensor(3.8751, grad_fn=<AddBackward0>)
# X = tensor(-0.2448, requires_grad=True), f(x) = tensor(3.8751, grad_fn=<AddBackward0>)
# X = tensor(-0.2449, requires_grad=True), f(x) = tensor(3.8751, grad_fn=<AddBackward0>)
# X = tensor(-0.2449, requires_grad=True), f(x) = tensor(3.8751, grad_fn=<AddBackward0>)
# X = tensor(-0.2449, requires_grad=True), f(x) = tensor(3.8751, grad_fn=<AddBackward0>)
# X = tensor(-0.2449, requires_grad=True), f(x) = tensor(3.8751, grad_fn=<AddBackward0>)
# X = tensor(-0.2450, requires_grad=True), f(x) = tensor(3.8751, grad_fn=<AddBackward0>)
# X = tensor(-0.2450, requires_grad=True), f(x) = tensor(3.8751, grad_fn=<AddBackward0>)
# X = tensor(-0.2450, requires_grad=True), f(x) = tensor(3.8751, grad_fn=<AddBackward0>)
# X = tensor(-0.2450, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2450, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2451, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2451, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2451, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2451, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2451, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2451, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2452, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2452, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2452, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2452, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2452, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2453, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2453, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2453, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2453, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2453, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2454, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2454, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2454, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2454, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2454, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2455, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2455, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2455, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2455, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2455, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2455, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2456, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2456, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2456, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2456, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2456, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2456, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2457, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2457, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2457, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2457, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2457, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2458, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2458, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2458, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2458, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2458, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2458, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2459, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2459, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2459, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2459, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2459, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2459, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2459, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2460, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2460, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2460, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2460, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2460, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2460, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2461, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2461, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2461, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2461, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2461, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2461, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2462, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2462, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2462, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2462, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2462, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2462, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2462, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2463, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2463, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2463, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2463, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2463, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2463, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2464, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2464, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2464, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2464, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2464, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2464, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2464, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2465, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2465, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2465, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2465, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2465, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2465, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2465, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2465, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2466, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2466, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2466, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2466, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2466, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2466, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2466, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2467, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2467, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2467, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2467, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2467, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2467, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2467, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2468, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2468, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2468, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2468, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2468, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2468, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2468, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2468, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2469, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2469, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2469, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2469, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2469, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2469, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2469, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2469, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2470, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2470, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2470, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2470, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2470, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2470, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2470, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2470, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2470, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2471, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2471, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2471, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2471, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2471, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2471, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2471, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2471, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2472, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2472, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2472, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2472, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2472, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2472, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2472, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2472, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2472, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2473, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)
# X = tensor(-0.2473, requires_grad=True), f(x) = tensor(3.8750, grad_fn=<AddBackward0>)

# %% [markdown]
# # c) Implementando un MLP en PyTorch para predicción del procentaje de grasa corporal
#
# Contamos con una base de datos [1] de 252 mediciones del porcentaje de grasa corporal de 252 personas diferentes, el cual puede ser estimado mediante otras características, como la edad, el peso, y mediciones en diferentes partes del cuerpo. A partir de estos datos se pretende desarrollar un sistema que permita predecir dicho porcentaje a partir de las características.
#
# [1]: Olson, R.S., La Cava, W., Orzechowski, P. et al. PMLB: a large benchmark suite for machine learning evaluation and comparison. BioData Mining 10, 36 (2017). https://epistasislab.github.io/pmlb/profile/560_bodyfat.html
#
# Antes de comenzar, vamos a instalar el paquete de Python que contiene la base de datos:

# %%
pip install pmlb
# Out:
# Requirement already satisfied: pmlb in /usr/local/lib/python3.10/dist-packages (1.0.1.post3)
# Requirement already satisfied: pandas>=1.0.5 in /usr/local/lib/python3.10/dist-packages (from pmlb) (2.0.3)
# Requirement already satisfied: requests>=2.24.0 in /usr/local/lib/python3.10/dist-packages (from pmlb) (2.31.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from pmlb) (6.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.5->pmlb) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.5->pmlb) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.5->pmlb) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.5->pmlb) (1.25.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.24.0->pmlb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.24.0->pmlb) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.24.0->pmlb) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.24.0->pmlb) (2024.2.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.5->pmlb) (1.16.0)

# %% [markdown]
# Ahora vamos a generar un histograma de todas las mediciones del porcentaje con todos los datos disponibles:
#
# > Añadir blockquote

# %%
import matplotlib.pyplot as plt
import numpy as np
from pmlb import fetch_data

# Importamos el dataset
body_fat = fetch_data('560_bodyfat')
body_fat.describe()

# Extraigo los datos (features) y los porcentajes (etiquetas a predecir)
data = body_fat.loc[:, body_fat.columns != 'target'].to_numpy()
percentages = body_fat.loc[:, body_fat.columns == 'target'].to_numpy()

data = data.astype(np.float32)
percentages = percentages.astype(np.float32)

print("Fila de ejemplo:")
print(list(body_fat.columns))
print(data[0,:])

# Dibujo un histograma del porcentaje de grasa corporal usando todos los datos
_ = plt.hist( data , 50, density=True, facecolor='g', alpha=0.75)
_ = plt.title("Porcentaje de grasa corporal")
# Out:
# Fila de ejemplo:
# ['Density', 'Age', 'Weight', 'Height', 'Neck', 'Chest', 'Abdomen', 'Hip', 'Thigh', 'Knee', 'Ankle', 'Biceps', 'Forearm', 'Wrist', 'target']
# [  1.0708  23.     154.25    67.75    36.2     93.1     85.2     94.5
#   59.      37.3     21.9     32.      27.4     17.1   ]

# %% [markdown]
# Particionamos los datos en entrenamiento y prueba usando la función `sklearn.model_selection.train_test_split`

# %%
 from sklearn.model_selection import train_test_split

 # Particiono los datos en entrenamiento y prueba usando el método de scikitlearn
 X_train, X_test, y_train, y_test = train_test_split( data , percentages , test_size=0.33, random_state=42)

# %% [markdown]
# Ahora implementaremos en PyTorch un Perceptrón multicapa que usaremos como regresor del porcentaje de grasa corporal (ejemplo basado en el curso de [RPI](https://rpi.analyticsdojo.com/)).
#
# El perceptrón deberá contar con 3 capas:
# - Las dos primeras con 200 neuronas, y deberán usar la función de activación ReLU.
# - La última con una única neurona cuya salida sea un valor escalar que corresponda al porcentaje de grasa corporal estimado de la persona, que no deberá utilizar ninguna función de activación.
#
# Algunas clases de PyTorch que resultarán útiles para implementar el modelo, son:
# - `torch.nn.Linear`: Implementa una capa totalmente conectada. Es necesario especificarle el número de parámetros de entrada y de salida.
# - `torch.nn.functional.relu`: Implementa la función de activación ReLU.
#
# Además, utilizaremos el optimizador `torch.optim.Adam` y la función de pérdida `torch.nn.MSELoss` (error cuadrático medio).

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader

# Tamaño del batch de entrenamiento
batch_size = 32

# Tasa de aprendizaje inicial para el gradiente descendente
learning_rate = 1e-3

class Net(torch.nn.Module):
    def __init__(self, input_features, size_hidden, n_output):
        super(Net, self).__init__()
        self.hidden1 = nn.Linear(input_features, size_hidden)
        self.hidden2 = nn.Linear(size_hidden, size_hidden)
        self.out = nn.Linear(size_hidden, n_output)

    def forward(self, x):
        x = torch.relu(self.hidden1(x))
        x = torch.relu(self.hidden2(x))
        x = self.out(x)
        return x

# Definimos el modelo del perceptrón
net = Net( X_train.shape[1], 2 , 1 )

# Construimos el optimizador, y le indicamos que los parámetros a optimizar
# son los del modelo definido: net.parameters()

optimizer = torch.optim.Adam( net.parameters() , lr=learning_rate)

# Definimos también la función de pérdida a utilizar
criterion = nn.MSELoss()

# Creamos el objeto dataset que empaqueta los array de numpy para que puedan
# ser leidos por PyTorch
dataset = TensorDataset(torch.from_numpy(X_train).clone(), torch.from_numpy(y_train).clone())

# Creamos un loader iterable indicandole que debe leer los datos a partir de
# del dataset creado en el paso anterior. Este objeto puede ser iterado
# y nos devuelve de a un batch (x, y).
loader = DataLoader(dataset=dataset, batch_size=batch_size, shuffle=True)

# Número de épocas
num_epochs = 5000

# Lista en la que iremos guardando el valor de la función de pérdida en cada
# etapa de entrenamiento
loss_list = []

# Bucle de entrenamiento
for i in range(num_epochs):

    total_loss = 0.0
    for x, y in loader:
        # Seteo en cero los gradientes de los parámetros a optimizar
        optimizer.zero_grad()

        # Realizo la pasada forward por la red
        loss = criterion( net(x), y)

        # Realizo la pasada backward por la red
        loss.backward()

        # Actualizo los pesos de la red con el optimizador
        optimizer.step()


        # Me guardo el valor actual de la función de pérdida para luego graficarlo
        loss_list.append(loss.data.item())

        # Acumulo la loss del minibatch
        total_loss += loss.item() * y.size(0)

    # Normalizo la loss total
    total_loss/= len(loader.dataset)

    # Muestro el valor de la función de pérdida cada 100 iteraciones
    if i > 0 and i % 100 == 0:
        print('Epoch %d, loss = %g' % (i, total_loss))

# Muestro la lista que contiene los valores de la función de pérdida
# y una versión suavizada (rojo) para observar la tendencia
plt.figure()
loss_np_array = np.array(loss_list)
plt.plot(loss_np_array, alpha = 0.3)
N = 60
running_avg_loss = np.convolve(loss_np_array, np.ones((N,))/N, mode='valid')
plt.plot(running_avg_loss, color='red')
plt.title("Función de pérdida durante el entrenamiento")
# Out:
# Epoch 100, loss = 55.2584
# Epoch 200, loss = 50.5992
# Epoch 300, loss = 42.2593
# Epoch 400, loss = 31.6998
# Epoch 500, loss = 28.0969
# Epoch 600, loss = 25.7668
# Epoch 700, loss = 25.3085
# Epoch 800, loss = 24.3064
# Epoch 900, loss = 23.5886
# Epoch 1000, loss = 22.9636
# Epoch 1100, loss = 22.2062
# Epoch 1200, loss = 21.9597
# Epoch 1300, loss = 21.7064
# Epoch 1400, loss = 21.444
# Epoch 1500, loss = 21.0758
# Epoch 1600, loss = 20.6487
# Epoch 1700, loss = 20.2938
# Epoch 1800, loss = 20.0831
# Epoch 1900, loss = 19.9601
# Epoch 2000, loss = 19.6521
# Epoch 2100, loss = 19.4149
# Epoch 2200, loss = 19.1622
# Epoch 2300, loss = 19.0373
# Epoch 2400, loss = 18.7889
# Epoch 2500, loss = 19.0411
# Epoch 2600, loss = 18.8473
# Epoch 2700, loss = 18.6759
# Epoch 2800, loss = 18.6904
# Epoch 2900, loss = 18.4857
# Epoch 3000, loss = 18.4941
# Epoch 3100, loss = 19.0365
# Epoch 3200, loss = 18.2895
# Epoch 3300, loss = 18.1461
# Epoch 3400, loss = 18.2446
# Epoch 3500, loss = 18.0299
# Epoch 3600, loss = 17.9811
# Epoch 3700, loss = 17.9714
# Epoch 3800, loss = 18.1905
# Epoch 3900, loss = 18.2498
# Epoch 4000, loss = 18.0163
# Epoch 4100, loss = 17.8204
# Epoch 4200, loss = 17.9277
# Epoch 4300, loss = 18.0437
# Epoch 4400, loss = 17.8233
# Epoch 4500, loss = 17.7628
# Epoch 4600, loss = 17.988
# Epoch 4700, loss = 17.9456
# Epoch 4800, loss = 17.5891
# Epoch 4900, loss = 17.6838
# Text(0.5, 1.0, 'Función de pérdida durante el entrenamiento')

# %%
from sklearn.linear_model import LinearRegression
from numpy.linalg import norm

# Definimos un método para mostrar las predicciones como un scatter plot
# y graficamos la recta de regresión para esos datos.
def plotScatter(x_data, y_data, title, fit_line=True):
  plt.figure()

  plt.plot(x_data, y_data, '+')
  plt.xlabel('Valor real')
  plt.ylabel('Predicción')
  plt.title(title)

  if fit_line:
    X, Y = x_data.reshape(-1,1), y_data.reshape(-1,1)
    plt.plot( X, LinearRegression().fit(X, Y).predict(X) )

# Dibujamos el ground truth vs las predicciones en los datos de entrenamiento
py = net(torch.FloatTensor(X_train))
y_pred_train = py.cpu().detach().numpy()
plotScatter(y_train, y_pred_train, "Training data")

# Dibujamos el ground truth vs las predicciones en los datos de test
py = net(torch.FloatTensor(X_test))
y_pred_test = py.cpu().detach().numpy()
plotScatter(y_test, y_pred_test, "Test data")

print ("MSE medio en training: " + str(((y_train - y_pred_train)**2).mean()))
print ("MSE medio en test: " + str(((y_test - y_pred_test)**2).mean()))
# Out:
# MSE medio en training: 15.526448
# MSE medio en test: 20.283075

# %%
from sklearn.linear_model import LinearRegression
from numpy.linalg import norm

# Definimos un método para mostrar las predicciones como un scatter plot
# y graficamos la recta de regresión para esos datos.
def plotScatter(x_data, y_data, title, fit_line=True):
  plt.figure()

  plt.plot(x_data, y_data, '+')
  plt.xlabel('Valor real')
  plt.ylabel('Predicción')
  plt.title(title)

  if fit_line:
    X, Y = x_data.reshape(-1,1), y_data.reshape(-1,1)
    plt.plot( X, LinearRegression().fit(X, Y).predict(X) )

# Dibujamos el ground truth vs las predicciones en los datos de entrenamiento
py = net(torch.FloatTensor(X_train))
y_pred_train = py.cpu().detach().numpy()
plotScatter(y_train, y_pred_train, "Training data")

# Dibujamos el ground truth vs las predicciones en los datos de test
py = net(torch.FloatTensor(X_test))
y_pred_test = py.cpu().detach().numpy()
plotScatter(y_test, y_pred_test, "Test data")

print ("MSE medio en training: " + str(((y_train - y_pred_train)**2).mean()))
print ("MSE medio en test: " + str(((y_test - y_pred_test)**2).mean()))
# Out:
# MSE medio en training: 18.01502
# MSE medio en test: 22.058388

# %%
from sklearn.linear_model import LinearRegression
from numpy.linalg import norm

# Definimos un método para mostrar las predicciones como un scatter plot
# y graficamos la recta de regresión para esos datos.
def plotScatter(x_data, y_data, title, fit_line=True):
  plt.figure()

  plt.plot(x_data, y_data, '+')
  plt.xlabel('Valor real')
  plt.ylabel('Predicción')
  plt.title(title)

  if fit_line:
    X, Y = x_data.reshape(-1,1), y_data.reshape(-1,1)
    plt.plot( X, LinearRegression().fit(X, Y).predict(X) )

# Dibujamos el ground truth vs las predicciones en los datos de entrenamiento
py = net(torch.FloatTensor(X_train))
y_pred_train = py.cpu().detach().numpy()
plotScatter(y_train, y_pred_train, "Training data")

# Dibujamos el ground truth vs las predicciones en los datos de test
py = net(torch.FloatTensor(X_test))
y_pred_test = py.cpu().detach().numpy()
plotScatter(y_test, y_pred_test, "Test data")

print ("MSE medio en training: " + str(((y_train - y_pred_train)**2).mean()))
print ("MSE medio en test: " + str(((y_test - y_pred_test)**2).mean()))
# Out:
# MSE medio en training: 3.8493493
# MSE medio en test: 40.435814

# %% [markdown]
# # Entregable
# 1. Encontrar el mínimo de la función *f* definida en el apartado b). Para ello, deberán encontrar primero la derivada *f'(x)* de forma analítica, y utilizarla para computar el mínimo de la función. Posteriormente, deberán corrobarar que el valor coincida con el que obtuvieron optimizando la función con gradiente descendiente.
#
# 2. Compara el rendimiento de 3 perceptrones multicapa que varíen en la cantidad de neuronas en sus capas intermedia. Probar colocando 2, 10 y 200 neuronas en dichas capas, al entrenar los perceptrones durante 5000 épocas. Mostrar los resultados utilizando:
#
# * los gráficos de dispersión con la recta de regresión
# * el error medio en los datos de entrenamiento y test
#
#   Analizar la relación entre dichos resultados y la cantidad de neuronas que posee el perceptrón.

# %%
1. la derivada de f(x) 4x+1. Eso nos da 0 cuando x = -0.25. Metiendo ese valor en la funcion nos da que el minimo es 3.875
# Out:
# /bin/bash: line 1: Si: command not found

# %%
2. Con 200 neuronas tenemos : MSE medio en training:  3.8493493, MSE medio en test: 40.43581  Los graficos se ven en la ultima slide.
Con 10 neuronas tenemos :MSE medio en training: 15.526448 MSE medio en test: 20.283075 Los graficos se ven en la primer slide.
Con 2 neuronas tenemos MSE medio en training: 18.01502 MSE medio en test: 22.058388 Los graficos se ven en la segunda slide.

llegamos a la conclusion de que con 200 neuronas estaba overfitiando. Probamos con menos epocas y el modelo funciono mejor.
